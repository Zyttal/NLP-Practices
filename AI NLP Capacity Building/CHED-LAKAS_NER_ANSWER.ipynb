# %% [markdown]
# ## Activity 1 (Topic 2) : Named Entity Recognition (NER using Spacy)  ###
# ---
# This exercise will give demonstrate how NLTK can be used to extract NER from documents. it will also give the participants some experience in testing and adjusting the parameters of the NLTK NER tools.

# %% [markdown]
# ### Step 1 : Importing and Loading Spacy
# ---
#
# During processing, spaCy first tokenizes the text, i.e. segments it into words, punctuation and so on. This is done by applying rules specific to each language. For example, punctuation at the end of a sentence should be split off – whereas “U.K.” should remain one token. Each Doc consists of individual tokens, and we can iterate over them:

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")
for token in doc:
    print(token.text)
# Out:
# Apple
# is
# looking
# at
# buying
# U.K.
# startup
# for
# $
# 1
# billion

# %% [markdown]
# ### Step 2 : linguistic annotations in Spacy
# ---
# spaCy provides a variety of linguistic annotations to give you insights into a text’s grammatical structure. This includes the word types, like the parts of speech, and how the words are related to each other. For example, if you’re analyzing text, it makes a huge difference whether a noun is the subject of a sentence, or the object – or whether “google” is used as a verb, or refers to the website or company in a specific context.

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# Apple PROPN nsubj
# is AUX aux
# looking VERB ROOT
# at ADP prep
# buying VERB pcomp
# U.K. PROPN dobj
# startup NOUN dep
# for ADP prep
# $ SYM quantmod
# 1 NUM compound
# billion NUM pobj

# %% [markdown]
# ### Step 3 : Tokenization in Spacy
# ---
# During processing, spaCy first tokenizes the text, i.e. segments it into words, punctuation and so on. This is done by applying rules specific to each language. For example, punctuation at the end of a sentence should be split off – whereas “U.K.” should remain one token. Each Doc consists of individual tokens, and we can iterate over them:

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")
for token in doc:
    print(token.text)
# Out:
# Apple
# is
# looking
# at
# buying
# U.K.
# startup
# for
# $
# 1
# billion

# %% [markdown]
# ### Step 4 : Named Entity Recognition using Spacy
# ---
# A named entity is a “real-world object” that’s assigned a name – for example, a person, a country, a product or a book title. spaCy can recognize various types of named entities in a document, by asking the model for a prediction. Because models are statistical and strongly depend on the examples they were trained on, this doesn’t always work perfectly and might need some tuning later, depending on your use case.
#
# Named entities are available as the ents property of a Doc:

# %%
def show_ents(doc):
  if doc.ents:
    for ent in doc.ents:
      print(ent.text+' - '+str(ent.start_char)+' - '+str(ent.end_char)+str(ent.label_)+' - '+str(spacy.explain(ent.label_)))
  else:
    print("No Named entities Found")

# %%
import spacy

ner = spacy.load("en_core_web_sm")
doc = ner("Doc Raga is teaching in AI-NLP in Batangas City, today (October 26, 2023)")
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)

print("\n\n")
doc2 = ner(u'May I go to Washington, DC next May to see the Washington Monument?')
show_ents(doc2)
#for ent in doc.ents:
#    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Doc Raga 0 8 PERSON
# AI-NLP 24 30 ORG
# Batangas City 34 47 GPE
# today 49 54 DATE
# October 26, 2023 56 72 DATE
#
#
#
# Washington, DC - 12 - 26GPE - Countries, cities, states
# next May - 27 - 35DATE - Absolute or relative dates or periods
# the Washington Monument - 43 - 66ORG - Companies, agencies, institutions, etc.

# %% [markdown]
# ### Step 4 : Interface for testing Named Entity Recognition using Spacy
# ---
#
# Enter a sample text and see if Spacy can identify the embedded NER

# %%
from spacy import displacy
sample_text = 'This is a sample text'
while sample_text != '?':
  sample_text = input('Enter a sample text:')
  print('Raw Text Data: \n',sample_text,'\n')
  doc = ner(sample_text)
  show_ents(doc)
  print('\n')
  displacy.render(doc,style="ent",jupyter=True)
print("Program ended")
# Out:
# Raw Text Data:
#  DENVER — Michael Malone thought of his father, legendary coach Brendan Malone, who recently passed away. The son wished his dad could have been at Ball Arena on Tuesday night to witness it all, the moment each of them wanted. Jamal Murray said the celebration of a championship was a lot better than he thought it would be. He, of course, was itching to just get to real basketball. And collectively, it was a great moment for the Denver Nuggets, watching a banner go high into the rafters.  Christian Braun and DeAndre Jordan allowed reporters to see and examine the bulky rings after the Nuggets took care of the Los Angeles Lakers in a 119-107 win before a sold-out and animated crowd. And the crowd, well, toward the end of Denver’s first win of the season, it chanted, “Who’s your daddy?” at the Lakers, an ode to a little trash talk from the championship parade in June.  For sure, there were plenty of extras Tuesday night as the curtain rose on another NBA season. But if there’s a message to be sent to the league, it’s this: These Denver Nuggets are for real, as if the championship they just won wasn’t enough of a hint. They are not a one-hit wonder. And whatever happens in this NBA season, these Nuggets are going to have a strong say in the outcome.
#
# DENVER - 0 - 6GPE - Countries, cities, states
# Michael Malone - 9 - 23PERSON - People, including fictional
# Brendan Malone - 63 - 77PERSON - People, including fictional
# Ball Arena - 147 - 157FAC - Buildings, airports, highways, bridges, etc.
# Tuesday - 161 - 168DATE - Absolute or relative dates or periods
# night - 169 - 174TIME - Times smaller than a day
# Jamal Murray - 226 - 238PERSON - People, including fictional
# the Denver Nuggets - 427 - 445ORG - Companies, agencies, institutions, etc.
# Christian Braun - 492 - 507ORG - Companies, agencies, institutions, etc.
# DeAndre Jordan - 512 - 526PERSON - People, including fictional
# Nuggets - 590 - 597ORG - Companies, agencies, institutions, etc.
# the Los Angeles Lakers - 611 - 633ORG - Companies, agencies, institutions, etc.
# 119 - 639 - 642CARDINAL - Numerals that do not fall under another type
# Denver - 728 - 734GPE - Countries, cities, states
# first - 737 - 742ORDINAL - "first", "second", etc.
# Lakers - 801 - 807PERSON - People, including fictional
# June - 871 - 875DATE - Absolute or relative dates or periods
# Tuesday - 916 - 923DATE - Absolute or relative dates or periods
# night - 924 - 929TIME - Times smaller than a day
# NBA - 961 - 964ORG - Companies, agencies, institutions, etc.
# These Denver Nuggets - 1035 - 1055ORG - Companies, agencies, institutions, etc.
# one - 1147 - 1150CARDINAL - Numerals that do not fall under another type
# NBA - 1192 - 1195ORG - Companies, agencies, institutions, etc.
# Nuggets - 1210 - 1217ORG - Companies, agencies, institutions, etc.
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DENVER
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  —
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michael Malone
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  thought of his father, legendary coach
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brendan Malone
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , who recently passed away. The son wished his dad could have been at
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ball Arena
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     night
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  to witness it all, the moment each of them wanted.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jamal Murray
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said the celebration of a championship was a lot better than he thought it would be. He, of course, was itching to just get to real basketball. And collectively, it was a great moment for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Denver Nuggets
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , watching a banner go high into the rafters.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Christian Braun
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DeAndre Jordan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  allowed reporters to see and examine the bulky rings after the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nuggets
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  took care of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Los Angeles Lakers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     119
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# -107 win before a sold-out and animated crowd. And the crowd, well, toward the end of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Denver
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ’s
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  win of the season, it chanted, “Who’s your daddy?” at the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lakers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , an ode to a little trash talk from the championship parade in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .  For sure, there were plenty of extras
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     night
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  as the curtain rose on another
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NBA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  season. But if there’s a message to be sent to the league, it’s this:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     These Denver Nuggets
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  are for real, as if the championship they just won wasn’t enough of a hint. They are not a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# -hit wonder. And whatever happens in this
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NBA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; bord
